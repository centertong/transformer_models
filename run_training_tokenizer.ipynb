# %%
from google.colab import drive
drive.mount('/content/drive')

# %cd /content/drive/My Drive/Projects/transformer/transformer/
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/My Drive/Projects/transformer/transformer

# %%
# !pip install tokenizers

# %%
#!python bin/train_tokenizer.py --normalizers BERT --pre_tokenizers BERT --model WP --post_process BERT --decoder WP --unk [UNK] --cls [CLS] --sep [SEP] --pad [PAD] --mask [MASK] --train_files data/kowiki/wiki.txt --output_dir vocab/bert/
#!python bin/train_tokenizer_with_json.py --config_file configs/bert.json --train_files data/kowiki/wiki.txt --output_dir vocab/bert2/

# %%
text = "아이유는 2008년 9월 23일에 발매된 첫 번째 미니 음반 Lost and Found를 통하여 가수로 데뷔하였다."

# %%
from tokenizers import Tokenizer

tokenizer = Tokenizer.from_file("vocab/bert2/tokenizer.json")
