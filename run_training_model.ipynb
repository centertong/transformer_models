# %%
from google.colab import drive
drive.mount('/content/drive')

# %cd /content/drive/My Drive/Projects/transformers/
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/My Drive/Projects/transformers

# %%
# !pip install transformers tokenizers kss
# !pip install reformer_pytorch

# %%
pythonpath: str = "/content/drive/My\ Drive/Projects/transformers/"
config: str = "configs/model/rfa.json"
tokenizer: str = "vocab/bert2/tokenizer.json"
save_path: str = "save/klue_tc/"
train_file: str = "data/kowiki/wiki_parsed.txt"

# !PYTHONPATH=$pythonpath python bin/train_klue.py --config $config --tokenizer $tokenizer --train_file $train_file --save_path $save_path --epochs 5 --batch_size 24 --name rfa
# Out:
#   0% 0/1 [00:00<?, ?it/s]
# Data load for pretraining: 0it [00:00, ?it/s]
# Data load for pretraining: 27819it [00:00, 278154.45it/s]
# Data load for pretraining: 56383it [00:00, 263713.78it/s]
#   0% 0/1 [00:00<?, ?it/s]
# Epoch-0 Iterator: 100% 1126/1126 [07:12<00:00,  2.60it/s, 2021-11-21 07:25:26.396525 | Train Loss: 8.965328216552734 | Steps: 1126]
# Evaluating: 100% 63/63 [00:14<00:00,  4.21it/s]
# 0.5224776982315003
# Epoch-1 Iterator: 100% 1126/1126 [07:16<00:00,  2.58it/s, 2021-11-21 07:32:57.445442 | Train Loss: 0.3439493775367737 | Steps: 2252]
# Evaluating: 100% 63/63 [00:14<00:00,  4.43it/s]
# 0.5037447829095144
# Epoch-2 Iterator: 100% 1126/1126 [07:20<00:00,  2.56it/s, 2021-11-21 07:40:31.765052 | Train Loss: 0.34163421392440796 | Steps: 3378]
# Evaluating: 100% 63/63 [00:14<00:00,  4.44it/s]
# 0.525907689143741
# Epoch-3 Iterator: 100% 1126/1126 [07:22<00:00,  2.54it/s, 2021-11-21 07:48:08.413852 | Train Loss: 0.7373790144920349 | Steps: 4504]
# ...
