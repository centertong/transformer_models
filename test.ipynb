# %%
import torch
import torch.nn as nn
# !pip install transformers
from transformers.optimization import Adafactor
import torch.optim as opt
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.7/dist-packages (4.12.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.4.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.1.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (0.1.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.19.5)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (6.0)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.7/dist-packages (from transformers) (0.0.46)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.62.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.8.2)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (0.10.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers) (3.10.0.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.6)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.6.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.1.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (7.1.2)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.15.0)

# %%
a = torch.randn(32, 100, 1)  
m = nn.Conv1d(100, 100, 1) 


# optimizer = Adafactor(m.parameters(), lr= 1e-3, relative_step=False)
optimizer = opt.Adam(m.parameters(), lr= 1e-3)

# %%
out = (m(a) ** 2).sum()
out.backward()
optimizer.step()

# %%
import torch

# %%
A =torch.nn.Conv1d(10, 10, 3, groups=10)

# %%
A.weight.size()
# Out:
# torch.Size([10, 1, 3])

# %%
from models.layers.convs import LightweightConv1d

LightweightConv1d(10, 10, 2, (3,), padding="same")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/sr/fydc68gs3qsfq3zcwj0957y80000gn/T/ipykernel_41368/2532590932.py in <module>
#       1 from models.layers.convs import LightweightConv1d
#       2
# ----> 3 LightweightConv1d(10, 10, 2, (3,), padding="same")
#
# /Volumes/GoogleDrive/내 드라이브/Projects/transformers/models/layers/convs.py in __init__(self, in_channels, out_channels, shared, kernel, padding)
#      22
#      23         self.s = shared
# ---> 24         self.conv = DepthwiseConv1d(in_channels=in_channels / shared, out_channels=out_channels / shared, kernel=kernel, padding=padding)
#      25
#      26     def forward(self, x):
#
# /Volumes/GoogleDrive/내 드라이브/Projects/transformers/models/layers/convs.py in __init__(self, in_channels, out_channels, kernel, padding)
#       8
#       9         assert out_channels % in_channels == 0
# ---> 10         self.conv = nn.Conv1d(in_channels=in_channels, out_channels=out_channels, kernel_size=kernel, padding=padding, groups=in_channels)
#      11
#      12
#
# ~/miniforge3/envs/torch/lib/python3.8/site-packages/torch/nn/modules/conv.py in __init__(self, in_channels, out_channels, kernel_size, stride, padding, dilation, groups, bias, padding_mode, device, dtype)
#     286         padding_ = padding if isinstance(padding, str) else _single(padding)
#     287         dilation_ = _single(dilation)
# --> 288         super(Conv1d, self).__init__(
#     289             in_channels, out_channels, kernel_size_, stride_, padding_, dilation_,
#     290             False, _single(0), groups, bias, padding_mode, **factory_kwargs)
#
# ~/miniforge3/envs/torch/lib/python3.8/site-packages/torch/nn/modules/conv.py in __init__(self, in_channels, out_channels, kernel_size, stride, padding, dilation, transposed, output_padding, groups, bias, padding_mode, device, dtype)
#     129                 (in_channels, out_channels // groups, *kernel_size), **factory_kwargs))
#     130         else:
# --> 131             self.weight = Parameter(torch.empty(
#     132                 (out_channels, in_channels // groups, *kernel_size), **factory_kwargs))
#     133         if bias:
#
# TypeError: empty() received an invalid combination of arguments - got (tuple, dtype=NoneType, device=NoneType), but expected one of:
#  * (tuple of ints size, *, tuple of names names, torch.memory_format memory_format, torch.dtype dtype, torch.layout layout, torch.device device, bool pin_memory, bool requires_grad)
#  * (tuple of ints size, *, torch.memory_format memory_format, Tensor out, torch.dtype dtype, torch.layout layout, torch.device device, bool pin_memory, bool requires_grad)

# %%
import torch

# %%
torch.einsum("ijd -> (ij)d", torch.arange(8).view(2,2,2))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4464/2361509333.py in <module>
# ----> 1 torch.einsum("ijd -> (ij)d", torch.arange(8).view(2,2,2))
#
# ~\miniconda3\envs\ml\lib\site-packages\torch\functional.py in einsum(*args)
#     325         return einsum(equation, *_operands)
#     326
# --> 327     return _VF.einsum(equation, operands)  # type: ignore[attr-defined]
#     328
#     329
#
# RuntimeError: einsum(): invalid subscript given at index 7 in the equation string, subscripts must be in [a-zA-Z]

# %%
A - A.mean(dim=-1).unsqueeze(1)
# Out:
# tensor([[ 0.1179,  0.0993, -0.2172],
#         [-0.1279,  0.1828, -0.0550],
#         [ 0.2735, -0.5804,  0.3069],
#         [ 0.0572,  0.0972, -0.1545],
#         [ 0.1634, -0.2792,  0.1157],
#         [ 0.2182, -0.2354,  0.0172],
#         [-0.4496,  0.4098,  0.0398],
#         [ 0.1627, -0.4162,  0.2535]])
